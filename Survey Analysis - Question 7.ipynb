# %%
import pandas as pd

# %%
#load question 3 from survey into pandas (What do you find most useful about the Community Tool Box?)
q3_df = pd.read_csv('data/question7.csv')
pd.set_option('display.max_colwidth', None)
q3_df
# Out:
#                                                                                     Community Tool Box User Survey  \
# 0    (Optional) If you would like, please provide your email address so that we may follow-up with you, as needed:
# 1                                                                                                   Answer Options
# 2                                                                                                              NaN
# 3                                                                                                answered question
# 4                                                                                                 skipped question
# ..                                                                                                             ...
# 115                                                                                                            109
# 116                                                                                                            110
# 117                                                                                                            111
# 118                                                                                                            112
# 119                                                                                                            113
#
#                                                                                   Community Tool Box User Survey.1  \
# 0    (Optional) If you would like, please provide your email address so that we may follow-up with you, as needed:
# 1                                                                                                   Answer Options
# 2                                                                                                              NaN
# 3                                                                                                              113
# 4                                                                                                              212
# ..                                                                                                             ...
# 115                                                                                           Mar 28, 2017 4:58 PM
# 116                                                                                           Mar 28, 2017 4:42 PM
# 117                                                                                           Mar 28, 2017 4:40 PM
# 118                                                                                           Mar 28, 2017 4:39 PM
# 119                                                                                           Mar 28, 2017 4:30 PM
#
#                                                                                   Community Tool Box User Survey.2  \
# 0    (Optional) If you would like, please provide your email address so that we may follow-up with you, as needed:
# 1                                                                                                   Response Count
# 2                                                                                                              113
# 3                                                                                                              113
# 4                                                                                                              212
# ..                                                                                                             ...
# 115                                                                                                brydzo2@uic.edu
# 116                                                                                            jbeck@regionsix.com
# 117                                                                                           marcomeneses@msn.com
# 118                                                                                        jeffrey.sheldon@cgu.edu
# 119                                                                                      samuelhenriquez@gmail.com
#
#     Unnamed: 3
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 115        NaN
# 116        NaN
# 117        NaN
# 118        NaN
# 119        NaN
#
# [120 rows x 4 columns]
